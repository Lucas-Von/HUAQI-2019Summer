# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import matplotlib.pylab as plt
from sklearn.svm import SVC
import missingno as msno
from fancyimpute import KNN
# Out:
# Using TensorFlow backend.

# %%
m=pd.read_csv('origin_class.csv')
#d=pd.concat([m['风险等级'],d],axis=1)
#d.to_csv('origin.csv',encoding='utf-8-sig',index=False)

# %%
def KNNtrans(d):
    m= KNN(k=20).fit_transform(d)
    m=pd.DataFrame(m,columns=d.columns)
    return m
#d_np_corr=np.array(d.corr('spearman'))

# %%
d=m
d[1:]=KNNtrans(m[1:])
# Out:
# Imputing row 1/4031 with 1 missing, elapsed time: 14.416
# Imputing row 101/4031 with 2 missing, elapsed time: 14.426
# Imputing row 201/4031 with 0 missing, elapsed time: 14.437
# Imputing row 301/4031 with 1 missing, elapsed time: 14.446
# Imputing row 401/4031 with 1 missing, elapsed time: 14.460
# Imputing row 501/4031 with 0 missing, elapsed time: 14.471
# Imputing row 601/4031 with 0 missing, elapsed time: 14.481
# Imputing row 701/4031 with 0 missing, elapsed time: 14.493
# Imputing row 801/4031 with 3 missing, elapsed time: 14.503
# Imputing row 901/4031 with 2 missing, elapsed time: 14.512
# Imputing row 1001/4031 with 2 missing, elapsed time: 14.519
# Imputing row 1101/4031 with 0 missing, elapsed time: 14.532
# Imputing row 1201/4031 with 1 missing, elapsed time: 14.551
# Imputing row 1301/4031 with 1 missing, elapsed time: 14.569
# Imputing row 1401/4031 with 0 missing, elapsed time: 14.580
# Imputing row 1501/4031 with 0 missing, elapsed time: 14.591
# Imputing row 1601/4031 with 0 missing, elapsed time: 14.600
# Imputing row 1701/4031 with 0 missing, elapsed time: 14.615
# Imputing row 1801/4031 with 5 missing, elapsed time: 14.643
# Imputing row 1901/4031 with 0 missing, elapsed time: 14.662
# Imputing row 2001/4031 with 1 missing, elapsed time: 14.680
# Imputing row 2101/4031 with 0 missing, elapsed time: 14.702
# Imputing row 2201/4031 with 0 missing, elapsed time: 14.718
# Imputing row 2301/4031 with 1 missing, elapsed time: 14.730
# Imputing row 2401/4031 with 1 missing, elapsed time: 14.747
# Imputing row 2501/4031 with 0 missing, elapsed time: 14.759
# Imputing row 2601/4031 with 0 missing, elapsed time: 14.769
# Imputing row 2701/4031 with 0 missing, elapsed time: 14.781
# Imputing row 2801/4031 with 2 missing, elapsed time: 14.803
# Imputing row 2901/4031 with 2 missing, elapsed time: 14.825
# Imputing row 3001/4031 with 0 missing, elapsed time: 14.839
# Imputing row 3101/4031 with 1 missing, elapsed time: 14.875
# Imputing row 3201/4031 with 0 missing, elapsed time: 14.906
# Imputing row 3301/4031 with 0 missing, elapsed time: 14.927
# Imputing row 3401/4031 with 0 missing, elapsed time: 14.949
# Imputing row 3501/4031 with 0 missing, elapsed time: 14.972
# Imputing row 3601/4031 with 0 missing, elapsed time: 14.986
# Imputing row 3701/4031 with 1 missing, elapsed time: 14.999
# Imputing row 3801/4031 with 0 missing, elapsed time: 15.013
# Imputing row 3901/4031 with 0 missing, elapsed time: 15.030
# Imputing row 4001/4031 with 0 missing, elapsed time: 15.049

# %%
# 两两相除
a = pd.Series(d['风险等级'])

for i in range(len(d.columns)):
    col_i=d.columns[i]
    if col_i == '风险等级':
        continue
    for j in range(i,len(d.columns)):
        col_j=d.columns[j]
        if col_j == '风险等级':
            continue
        new_col_name = col_i + ' ÷ ' + col_j
        tmp = d.apply(lambda x: x[col_i] / (x[col_j] + 0.0001), axis=1)
        tmp_1= d.apply(lambda x: x[col_j] / (x[col_i] + 0.0001), axis=1)
        tmp_b = pd.Series(tmp)
        tmp_b_1= pd.Series(tmp_1)
        tmp_score = a.corr(tmp_b, method='spearman')
        tmp_score_1 = a.corr(tmp_b, method='spearman')
        if tmp_score >= 0.3 or tmp_score <= -0.3:
            kkk=a.corr(d[col_i],method='spearman')
            mmm=a.corr(d[col_j],method='spearman')
            if np.abs(tmp_score)>np.abs(kkk)+0.03 and np.abs(tmp_score)>np.abs(mmm)+0.03:
                print(new_col_name + ':', tmp_score, end='')
                #print('【*****】')
                print(' ',kkk,' ',mmm)
                #file_out = open('valuable_new_2.txt', 'a')
                #print(new_col_name + ':', tmp_score, file = file_out)
                #file_out.close()
        #else:
            #print()
# Out:
# 金融信息关注程度a4002a ÷ 银行储蓄卡数量d1103: -0.4115368260144178  -0.33515436182055475   0.36242415716665227
# 金融信息关注程度a4002a ÷ 去年平均每月伙食费g1001: -0.3943337733594161  -0.33515436182055475   0.3097911528634667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-817-3170ba8d0fcc> in <module>()
#      12         new_col_name = col_i + ' ÷ ' + col_j
#      13         tmp = d.apply(lambda x: x[col_i] / (x[col_j] + 0.0001), axis=1)
# ---> 14         tmp_1= d.apply(lambda x: x[col_j] / (x[col_i] + 0.0001), axis=1)
#      15         tmp_b = pd.Series(tmp)
#      16         tmp_b_1= pd.Series(tmp_1)
#
# d:\python\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# d:\python\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4931                     labels = self._get_agg_axis(axis)
#    4932                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4933                                         labels=labels)
#    4934                     return Series(result, index=labels)
#    4935                 except Exception:
#
# pandas/_libs/src\reduce.pyx in pandas._libs.lib.reduce()
#
# pandas/_libs/src\reduce.pyx in pandas._libs.lib.Reducer.get_result()
#
# d:\python\lib\site-packages\pandas\core\series.py in name(self, value)
#     340     @name.setter
#     341     def name(self, value):
# --> 342         if value is not None and not is_hashable(value):
#     343             raise TypeError('Series.name must be a hashable type')
#     344         object.__setattr__(self, '_name', value)
#
# d:\python\lib\site-packages\pandas\core\dtypes\inference.py in is_hashable(obj)
#     388
#     389     try:
# --> 390         hash(obj)
#     391     except TypeError:
#     392         return False
#
# KeyboardInterrupt:

# %%
for i in range(len(d_np_corr)):
    for j in range(len(d_np_corr[i])):
        if d_np_corr[i][j]>=0.5:
            if i!=j:
                print(str(d_np_corr[i][j])+'  '+d.columns[i]+'  '+d.columns[j])
# Out:
# 0.5406727502005961  金融信息关注程度a4002a  金融信息/伙食费
# 0.5589302548050061  金融信息关注程度a4002a  风险汇报选择/旅游
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-818-c375b9197591> in <module>()
#       3         if d_np_corr[i][j]>=0.5:
#       4             if i!=j:
# ----> 5                 print(str(d_np_corr[i][j])+'  '+d.columns[i]+'  '+d.columns[j])
#
# d:\python\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    1741
#    1742         if is_scalar(key):
# -> 1743             return getitem(key)
#    1744
#    1745         if isinstance(key, slice):
#
# IndexError: index 23 is out of bounds for axis 0 with size 23

# %%
print(len(d_np_corr[0]))
for i in range(len(d_np_corr[0])):
    if np.abs(d_np_corr[0][i])<=0.3:
        print(str(d_np_corr[0][i])+'  '+d.columns[i]+'  '+d.columns[0])
# Out:
# 29
# -0.06054581934723006  互联网产品类别非2，3，7加权  风险等级
# -0.050888924951964336  互联网产品类别2，3，7加权  风险等级
# -0.27619314822488283  股票和基金风险更大a4007  风险等级
# -0.2641495790851265  股票/耐用品  风险等级
# 0.26954708960200113  耐用品总价值c8002  风险等级
# 0.23394297132184125  活期存款余额d1105  风险等级
# 0.2328773905554694  定期存款总额d2104_imp  风险等级
# 0.2671245504918144  去年平均每月水/电/燃料费/物业g1005  风险等级
# 0.2736258319911396  去年平均每月购买日常用品支出g1006  风险等级
# 0.27750375295742913  去年平均每月本地交通支出g1008_imp  风险等级
# 0.2506461039510412  去年每月通信费支出g1009_imp  风险等级
# 0.28427640016163636  去年购买衣物支出g1011_imp  风险等级
# 0.18805503314990174  去年购买家庭耐用品支出g1014_imp  风险等级
# 0.13784967046088137  去年教育培训支出g1016_imp  风险等级

# %%
msno.matrix(d)

# %%
y=d['风险等级']
X=d.drop(['风险等级'],axis=1)

X_train=pd.DataFrame()
y_train=pd.DataFrame()
X_test=pd.DataFrame()
y_test=pd.DataFrame()
for i in range(5):
    d_temp=d[d['风险等级']==i]
    y=d_temp['风险等级']
    X=d_temp.drop(['风险等级'],axis=1)
    X_train_temp,X_test_temp,y_train_temp,y_test_temp =train_test_split(X,y,test_size=0.1,random_state=12)
    X_train=pd.concat([X_train,X_train_temp],axis=0)
    y_train=pd.concat([y_train,y_train_temp],axis=0)
    #for j in range(2):
    #    if i!=0:
    #        X_train=pd.concat([X_train,X_train_temp],axis=0)
    #        y_train=pd.concat([y_train,y_train_temp],axis=0)
    X_test=pd.concat([X_test,X_test_temp],axis=0)
    y_test=pd.concat([y_test,y_test_temp],axis=0)
    
#X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.3,random_state=12)
#train_X_y=pd.concat([y_train,X_train],axis=1)
#test_X_y=pd.concat([y_test,X_test],axis=1)

# %%
train_X_y=pd.concat([y_train,X_train],axis=1)
test_X_y=pd.concat([y_test,X_test],axis=1)
#train_X_y=KNNtrans(train_X_y)
train_X_y_temp=train_X_y.reset_index(drop=True)

train_X_y=train_X_y_temp[1900:].sample(frac=1,random_state=1)

test_X_y=test_X_y.sample(frac=1,random_state=1).reset_index(drop=True)

y_train=train_X_y[0]
X_train=train_X_y.drop([0],axis=1)
y_test=test_X_y[0]
X_test=test_X_y.drop([0],axis=1)

# %%
lgb_train = lgb.Dataset(X_train, y_train) 
lgb_eval = lgb.Dataset(X_test, y_test, reference=lgb_train)

# %%
params = {
    'task': 'train',
    'nthread':'6',
    'boosting_type': 'gbdt',  # 设置提升类型
    #'objective': 'multiclass', # 目标函数
    'objective': 'multiclass',
    'num_leaves': 10,   # 叶子节点数
    'learning_rate': 0.01,  # 学习速率
    'max_depth':4,
    'subsample':0.8,
    'colsample_bytree':0.6,
    'max_bin':10000,
    'min_data_in_leaf':10,
    'lambda_l1':3,
    'lambda_l2': 3,
    'feature_fraction': 0.9, # 建树的特征选择比例
    #'bagging_fraction': 0.9, # 建树的样本采样比例
    #'bagging_freq': 5,  # k 意味着每 k 次迭代执行bagging
    'verbose': 1, # <0 显示致命的, =0 显示错误 (警告), >0 显示信息
    'num_class':5
}
 
print('Start training...')

gbm = lgb.train(params,lgb_train,num_boost_round=2000,valid_sets=lgb_eval,early_stopping_rounds=100,categorical_feature=[1,2])
# Out:
# Start training...
# [1]	valid_0's multi_logloss: 1.18293
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 1.17887
# [3]	valid_0's multi_logloss: 1.17461
# [4]	valid_0's multi_logloss: 1.1702
# [5]	valid_0's multi_logloss: 1.16616
# [6]	valid_0's multi_logloss: 1.16196
# [7]	valid_0's multi_logloss: 1.15771
# [8]	valid_0's multi_logloss: 1.15349
# [9]	valid_0's multi_logloss: 1.14976
# [10]	valid_0's multi_logloss: 1.14567
# [11]	valid_0's multi_logloss: 1.14264
# [12]	valid_0's multi_logloss: 1.13865
# [13]	valid_0's multi_logloss: 1.13502
# [14]	valid_0's multi_logloss: 1.13109
# [15]	valid_0's multi_logloss: 1.12739
# [16]	valid_0's multi_logloss: 1.1236
# [17]	valid_0's multi_logloss: 1.1198
# [18]	valid_0's multi_logloss: 1.11607
# [19]	valid_0's multi_logloss: 1.11253
# [20]	valid_0's multi_logloss: 1.10892
# [21]	valid_0's multi_logloss: 1.10544
# [22]	valid_0's multi_logloss: 1.1029
# [23]	valid_0's multi_logloss: 1.09937
# [24]	valid_0's multi_logloss: 1.09603
# [25]	valid_0's multi_logloss: 1.09254
# [26]	valid_0's multi_logloss: 1.09037
# [27]	valid_0's multi_logloss: 1.08694
# [28]	valid_0's multi_logloss: 1.08361
# [29]	valid_0's multi_logloss: 1.08033
# [30]	valid_0's multi_logloss: 1.07709
# [31]	valid_0's multi_logloss: 1.07402
# [32]	valid_0's multi_logloss: 1.07178
# [33]	valid_0's multi_logloss: 1.06987
# [34]	valid_0's multi_logloss: 1.06679
# [35]	valid_0's multi_logloss: 1.06373
# [36]	valid_0's multi_logloss: 1.06066
# [37]	valid_0's multi_logloss: 1.05767
# [38]	valid_0's multi_logloss: 1.05479
# [39]	valid_0's multi_logloss: 1.05192
# [40]	valid_0's multi_logloss: 1.0499
# [41]	valid_0's multi_logloss: 1.04733
# [42]	valid_0's multi_logloss: 1.04528
# [43]	valid_0's multi_logloss: 1.0425
# [44]	valid_0's multi_logloss: 1.04057
# [45]	valid_0's multi_logloss: 1.03769
# [46]	valid_0's multi_logloss: 1.03503
# [47]	valid_0's multi_logloss: 1.03243
# [48]	valid_0's multi_logloss: 1.02998
# [49]	valid_0's multi_logloss: 1.02737
# [50]	valid_0's multi_logloss: 1.02486
# [51]	valid_0's multi_logloss: 1.0225
# [52]	valid_0's multi_logloss: 1.01998
# [53]	valid_0's multi_logloss: 1.01817
# [54]	valid_0's multi_logloss: 1.01561
# [55]	valid_0's multi_logloss: 1.01326
# [56]	valid_0's multi_logloss: 1.01086
# [57]	valid_0's multi_logloss: 1.00882
# [58]	valid_0's multi_logloss: 1.00657
# [59]	valid_0's multi_logloss: 1.00423
# [60]	valid_0's multi_logloss: 1.0027
# [61]	valid_0's multi_logloss: 1.00044
# [62]	valid_0's multi_logloss: 0.998192
# [63]	valid_0's multi_logloss: 0.995903
# [64]	valid_0's multi_logloss: 0.993704
# [65]	valid_0's multi_logloss: 0.99144
# [66]	valid_0's multi_logloss: 0.989342
# [67]	valid_0's multi_logloss: 0.987235
# [68]	valid_0's multi_logloss: 0.985407
# [69]	valid_0's multi_logloss: 0.983896
# [70]	valid_0's multi_logloss: 0.981951
# [71]	valid_0's multi_logloss: 0.98058
# [72]	valid_0's multi_logloss: 0.978552
# [73]	valid_0's multi_logloss: 0.976748
# [74]	valid_0's multi_logloss: 0.974863
# [75]	valid_0's multi_logloss: 0.972894
# [76]	valid_0's multi_logloss: 0.970871
# [77]	valid_0's multi_logloss: 0.968983
# [78]	valid_0's multi_logloss: 0.967185
# [79]	valid_0's multi_logloss: 0.965247
# [80]	valid_0's multi_logloss: 0.96334
# [81]	valid_0's multi_logloss: 0.961527
# [82]	valid_0's multi_logloss: 0.96044
# [83]	valid_0's multi_logloss: 0.95864
# [84]	valid_0's multi_logloss: 0.956868
# [85]	valid_0's multi_logloss: 0.954939
# [86]	valid_0's multi_logloss: 0.953832
# [87]	valid_0's multi_logloss: 0.952075
# [88]	valid_0's multi_logloss: 0.950627
# [89]	valid_0's multi_logloss: 0.949153
# [90]	valid_0's multi_logloss: 0.947299
# [91]	valid_0's multi_logloss: 0.946228
# [92]	valid_0's multi_logloss: 0.944544
# [93]	valid_0's multi_logloss: 0.943168
# [94]	valid_0's multi_logloss: 0.942267
# [95]	valid_0's multi_logloss: 0.941195
# [96]	valid_0's multi_logloss: 0.939682
# [97]	valid_0's multi_logloss: 0.938065
# [98]	valid_0's multi_logloss: 0.936547
# [99]	valid_0's multi_logloss: 0.934962
# [100]	valid_0's multi_logloss: 0.933274
# [101]	valid_0's multi_logloss: 0.931795
# [102]	valid_0's multi_logloss: 0.930211
# [103]	valid_0's multi_logloss: 0.928573
# [104]	valid_0's multi_logloss: 0.927136
# [105]	valid_0's multi_logloss: 0.925719
# [106]	valid_0's multi_logloss: 0.924479
# [107]	valid_0's multi_logloss: 0.923502
# [108]	valid_0's multi_logloss: 0.921972
# [109]	valid_0's multi_logloss: 0.920743
# [110]	valid_0's multi_logloss: 0.919503
# [111]	valid_0's multi_logloss: 0.9181
# [112]	valid_0's multi_logloss: 0.916615
# [113]	valid_0's multi_logloss: 0.915208
# [114]	valid_0's multi_logloss: 0.91409
# [115]	valid_0's multi_logloss: 0.912869
# [116]	valid_0's multi_logloss: 0.911418
# [117]	valid_0's multi_logloss: 0.91026
# [118]	valid_0's multi_logloss: 0.909161
# [119]	valid_0's multi_logloss: 0.908206
# [120]	valid_0's multi_logloss: 0.907395
# [121]	valid_0's multi_logloss: 0.906222
# [122]	valid_0's multi_logloss: 0.905148
# [123]	valid_0's multi_logloss: 0.903939
# [124]	valid_0's multi_logloss: 0.902585
# [125]	valid_0's multi_logloss: 0.901644
# [126]	valid_0's multi_logloss: 0.900311
# [127]	valid_0's multi_logloss: 0.899388
# [128]	valid_0's multi_logloss: 0.898115
# [129]	valid_0's multi_logloss: 0.8969
# [130]	valid_0's multi_logloss: 0.895765
# [131]	valid_0's multi_logloss: 0.894791
# [132]	valid_0's multi_logloss: 0.893674
# [133]	valid_0's multi_logloss: 0.892746
# [134]	valid_0's multi_logloss: 0.891429
# [135]	valid_0's multi_logloss: 0.89032
# [136]	valid_0's multi_logloss: 0.889104
# [137]	valid_0's multi_logloss: 0.887821
# [138]	valid_0's multi_logloss: 0.88672
# [139]	valid_0's multi_logloss: 0.885623
# [140]	valid_0's multi_logloss: 0.88456
# [141]	valid_0's multi_logloss: 0.883634
# [142]	valid_0's multi_logloss: 0.882397
# [143]	valid_0's multi_logloss: 0.881592
# [144]	valid_0's multi_logloss: 0.880491
# [145]	valid_0's multi_logloss: 0.879622
# [146]	valid_0's multi_logloss: 0.878966
# [147]	valid_0's multi_logloss: 0.877923
# [148]	valid_0's multi_logloss: 0.877292
# [149]	valid_0's multi_logloss: 0.876643
# [150]	valid_0's multi_logloss: 0.875454
# [151]	valid_0's multi_logloss: 0.87474
# [152]	valid_0's multi_logloss: 0.873862
# [153]	valid_0's multi_logloss: 0.872873
# [154]	valid_0's multi_logloss: 0.871892
# [155]	valid_0's multi_logloss: 0.870939
# [156]	valid_0's multi_logloss: 0.869859
# [157]	valid_0's multi_logloss: 0.868754
# [158]	valid_0's multi_logloss: 0.867825
# [159]	valid_0's multi_logloss: 0.866844
# [160]	valid_0's multi_logloss: 0.865877
# [161]	valid_0's multi_logloss: 0.865322
# [162]	valid_0's multi_logloss: 0.864406
# [163]	valid_0's multi_logloss: 0.863419
# [164]	valid_0's multi_logloss: 0.862539
# [165]	valid_0's multi_logloss: 0.861545
# [166]	valid_0's multi_logloss: 0.860649
# [167]	valid_0's multi_logloss: 0.859769
# [168]	valid_0's multi_logloss: 0.858789
# [169]	valid_0's multi_logloss: 0.858075
# [170]	valid_0's multi_logloss: 0.857238
# [171]	valid_0's multi_logloss: 0.856334
# [172]	valid_0's multi_logloss: 0.85572
# [173]	valid_0's multi_logloss: 0.854849
# [174]	valid_0's multi_logloss: 0.854043
# [175]	valid_0's multi_logloss: 0.853076
# [176]	valid_0's multi_logloss: 0.852271
# [177]	valid_0's multi_logloss: 0.851667
# [178]	valid_0's multi_logloss: 0.850735
# [179]	valid_0's multi_logloss: 0.849939
# [180]	valid_0's multi_logloss: 0.849062
# [181]	valid_0's multi_logloss: 0.848542
# [182]	valid_0's multi_logloss: 0.847675
# [183]	valid_0's multi_logloss: 0.846874
# [184]	valid_0's multi_logloss: 0.846161
# [185]	valid_0's multi_logloss: 0.845372
# [186]	valid_0's multi_logloss: 0.844567
# [187]	valid_0's multi_logloss: 0.843778
# [188]	valid_0's multi_logloss: 0.843277
# [189]	valid_0's multi_logloss: 0.842504
# [190]	valid_0's multi_logloss: 0.841625
# [191]	valid_0's multi_logloss: 0.840825
# [192]	valid_0's multi_logloss: 0.840119
# [193]	valid_0's multi_logloss: 0.839293
# [194]	valid_0's multi_logloss: 0.838549
# [195]	valid_0's multi_logloss: 0.83774
# [196]	valid_0's multi_logloss: 0.837127
# [197]	valid_0's multi_logloss: 0.836427
# [198]	valid_0's multi_logloss: 0.83589
# [199]	valid_0's multi_logloss: 0.835434
# [200]	valid_0's multi_logloss: 0.835017
# [201]	valid_0's multi_logloss: 0.834174
# [202]	valid_0's multi_logloss: 0.833577
# [203]	valid_0's multi_logloss: 0.832935
# [204]	valid_0's multi_logloss: 0.832046
# [205]	valid_0's multi_logloss: 0.831584
# [206]	valid_0's multi_logloss: 0.831056
# [207]	valid_0's multi_logloss: 0.830611
# [208]	valid_0's multi_logloss: 0.829991
# [209]	valid_0's multi_logloss: 0.829214
# [210]	valid_0's multi_logloss: 0.828748
# [211]	valid_0's multi_logloss: 0.82833
# [212]	valid_0's multi_logloss: 0.827669
# [213]	valid_0's multi_logloss: 0.82702
# [214]	valid_0's multi_logloss: 0.826557
# [215]	valid_0's multi_logloss: 0.825893
# [216]	valid_0's multi_logloss: 0.825346
# [217]	valid_0's multi_logloss: 0.824709
# [218]	valid_0's multi_logloss: 0.824358
# [219]	valid_0's multi_logloss: 0.823581
# [220]	valid_0's multi_logloss: 0.822953
# [221]	valid_0's multi_logloss: 0.822175
# [222]	valid_0's multi_logloss: 0.82182
# [223]	valid_0's multi_logloss: 0.821251
# [224]	valid_0's multi_logloss: 0.820658
# [225]	valid_0's multi_logloss: 0.820366
# [226]	valid_0's multi_logloss: 0.819956
# [227]	valid_0's multi_logloss: 0.819529
# [228]	valid_0's multi_logloss: 0.81895
# [229]	valid_0's multi_logloss: 0.818521
# [230]	valid_0's multi_logloss: 0.817898
# [231]	valid_0's multi_logloss: 0.817517
# [232]	valid_0's multi_logloss: 0.817328
# [233]	valid_0's multi_logloss: 0.817056
# [234]	valid_0's multi_logloss: 0.816664
# [235]	valid_0's multi_logloss: 0.816248
# [236]	valid_0's multi_logloss: 0.815775
# [237]	valid_0's multi_logloss: 0.815217
# [238]	valid_0's multi_logloss: 0.814765
# [239]	valid_0's multi_logloss: 0.814423
# [240]	valid_0's multi_logloss: 0.814
# [241]	valid_0's multi_logloss: 0.813748
# [242]	valid_0's multi_logloss: 0.81333
# [243]	valid_0's multi_logloss: 0.812876
# [244]	valid_0's multi_logloss: 0.812399
# [245]	valid_0's multi_logloss: 0.811978
# [246]	valid_0's multi_logloss: 0.811592
# [247]	valid_0's multi_logloss: 0.811016
# [248]	valid_0's multi_logloss: 0.810681
# [249]	valid_0's multi_logloss: 0.810503
# [250]	valid_0's multi_logloss: 0.810014
# [251]	valid_0's multi_logloss: 0.809729
# [252]	valid_0's multi_logloss: 0.809194
# [253]	valid_0's multi_logloss: 0.808996
# [254]	valid_0's multi_logloss: 0.808523
# [255]	valid_0's multi_logloss: 0.808086
# [256]	valid_0's multi_logloss: 0.807679
# [257]	valid_0's multi_logloss: 0.807279
# [258]	valid_0's multi_logloss: 0.806795
# [259]	valid_0's multi_logloss: 0.80632
# [260]	valid_0's multi_logloss: 0.805947
# [261]	valid_0's multi_logloss: 0.805617
# [262]	valid_0's multi_logloss: 0.805307
# [263]	valid_0's multi_logloss: 0.804964
# [264]	valid_0's multi_logloss: 0.804673
# [265]	valid_0's multi_logloss: 0.804235
# [266]	valid_0's multi_logloss: 0.803854
# [267]	valid_0's multi_logloss: 0.803442
# [268]	valid_0's multi_logloss: 0.80293
# [269]	valid_0's multi_logloss: 0.802565
# [270]	valid_0's multi_logloss: 0.802149
# [271]	valid_0's multi_logloss: 0.801709
# [272]	valid_0's multi_logloss: 0.801239
# [273]	valid_0's multi_logloss: 0.801073
# [274]	valid_0's multi_logloss: 0.800759
# [275]	valid_0's multi_logloss: 0.800528
# [276]	valid_0's multi_logloss: 0.800197
# [277]	valid_0's multi_logloss: 0.799781
# [278]	valid_0's multi_logloss: 0.799407
# [279]	valid_0's multi_logloss: 0.7992
# [280]	valid_0's multi_logloss: 0.798878
# [281]	valid_0's multi_logloss: 0.79865
# [282]	valid_0's multi_logloss: 0.798406
# [283]	valid_0's multi_logloss: 0.798162
# [284]	valid_0's multi_logloss: 0.797802
# [285]	valid_0's multi_logloss: 0.797439
# [286]	valid_0's multi_logloss: 0.797185
# [287]	valid_0's multi_logloss: 0.796909
# [288]	valid_0's multi_logloss: 0.796638
# [289]	valid_0's multi_logloss: 0.796206
# [290]	valid_0's multi_logloss: 0.795863
# [291]	valid_0's multi_logloss: 0.795504
# [292]	valid_0's multi_logloss: 0.795216
# [293]	valid_0's multi_logloss: 0.795067
# [294]	valid_0's multi_logloss: 0.794717
# [295]	valid_0's multi_logloss: 0.794323
# [296]	valid_0's multi_logloss: 0.794008
# [297]	valid_0's multi_logloss: 0.793732
# [298]	valid_0's multi_logloss: 0.79347
# [299]	valid_0's multi_logloss: 0.793159
# [300]	valid_0's multi_logloss: 0.792817
# [301]	valid_0's multi_logloss: 0.792458
# [302]	valid_0's multi_logloss: 0.792063
# [303]	valid_0's multi_logloss: 0.791756
# [304]	valid_0's multi_logloss: 0.791581
# [305]	valid_0's multi_logloss: 0.791336
# [306]	valid_0's multi_logloss: 0.791169
# [307]	valid_0's multi_logloss: 0.790818
# [308]	valid_0's multi_logloss: 0.79048
# [309]	valid_0's multi_logloss: 0.790198
# [310]	valid_0's multi_logloss: 0.790124
# [311]	valid_0's multi_logloss: 0.789805
# [312]	valid_0's multi_logloss: 0.789482
# [313]	valid_0's multi_logloss: 0.789135
# [314]	valid_0's multi_logloss: 0.788872
# [315]	valid_0's multi_logloss: 0.788598
# [316]	valid_0's multi_logloss: 0.788302
# [317]	valid_0's multi_logloss: 0.788094
# [318]	valid_0's multi_logloss: 0.78789
# [319]	valid_0's multi_logloss: 0.787765
# [320]	valid_0's multi_logloss: 0.787654
# [321]	valid_0's multi_logloss: 0.787522
# [322]	valid_0's multi_logloss: 0.787294
# [323]	valid_0's multi_logloss: 0.787085
# [324]	valid_0's multi_logloss: 0.786943
# [325]	valid_0's multi_logloss: 0.786767
# [326]	valid_0's multi_logloss: 0.78645
# [327]	valid_0's multi_logloss: 0.786232
# [328]	valid_0's multi_logloss: 0.78597
# [329]	valid_0's multi_logloss: 0.785877
# [330]	valid_0's multi_logloss: 0.785624
# [331]	valid_0's multi_logloss: 0.785345
# [332]	valid_0's multi_logloss: 0.785142
# [333]	valid_0's multi_logloss: 0.784888
# [334]	valid_0's multi_logloss: 0.78472
# [335]	valid_0's multi_logloss: 0.784459
# [336]	valid_0's multi_logloss: 0.784345
# [337]	valid_0's multi_logloss: 0.784193
# [338]	valid_0's multi_logloss: 0.784157
# [339]	valid_0's multi_logloss: 0.783901
# [340]	valid_0's multi_logloss: 0.783672
# [341]	valid_0's multi_logloss: 0.783413
# [342]	valid_0's multi_logloss: 0.783301
# [343]	valid_0's multi_logloss: 0.783128
# [344]	valid_0's multi_logloss: 0.78285
# [345]	valid_0's multi_logloss: 0.782606
# [346]	valid_0's multi_logloss: 0.782471
# [347]	valid_0's multi_logloss: 0.782206
# [348]	valid_0's multi_logloss: 0.782078
# [349]	valid_0's multi_logloss: 0.781828
# [350]	valid_0's multi_logloss: 0.781558
# [351]	valid_0's multi_logloss: 0.781278
# [352]	valid_0's multi_logloss: 0.781199
# [353]	valid_0's multi_logloss: 0.780996
# [354]	valid_0's multi_logloss: 0.780793
# [355]	valid_0's multi_logloss: 0.780659
# [356]	valid_0's multi_logloss: 0.780519
# [357]	valid_0's multi_logloss: 0.780299
# [358]	valid_0's multi_logloss: 0.780124
# [359]	valid_0's multi_logloss: 0.779919
# [360]	valid_0's multi_logloss: 0.779857
# [361]	valid_0's multi_logloss: 0.779745
# [362]	valid_0's multi_logloss: 0.77962
# [363]	valid_0's multi_logloss: 0.779499
# [364]	valid_0's multi_logloss: 0.779267
# [365]	valid_0's multi_logloss: 0.779202
# [366]	valid_0's multi_logloss: 0.779044
# [367]	valid_0's multi_logloss: 0.778806
# [368]	valid_0's multi_logloss: 0.778637
# [369]	valid_0's multi_logloss: 0.778404
# [370]	valid_0's multi_logloss: 0.778265
# [371]	valid_0's multi_logloss: 0.778112
# [372]	valid_0's multi_logloss: 0.778048
# [373]	valid_0's multi_logloss: 0.777824
# [374]	valid_0's multi_logloss: 0.777778
# [375]	valid_0's multi_logloss: 0.777696
# [376]	valid_0's multi_logloss: 0.777498
# [377]	valid_0's multi_logloss: 0.777375
# [378]	valid_0's multi_logloss: 0.77719
# [379]	valid_0's multi_logloss: 0.777182
# [380]	valid_0's multi_logloss: 0.777009
# [381]	valid_0's multi_logloss: 0.776771
# [382]	valid_0's multi_logloss: 0.776587
# [383]	valid_0's multi_logloss: 0.77651
# [384]	valid_0's multi_logloss: 0.776372
# [385]	valid_0's multi_logloss: 0.776236
# [386]	valid_0's multi_logloss: 0.776043
# [387]	valid_0's multi_logloss: 0.775946
# [388]	valid_0's multi_logloss: 0.77579
# [389]	valid_0's multi_logloss: 0.775626
# [390]	valid_0's multi_logloss: 0.775531
# [391]	valid_0's multi_logloss: 0.775356
# [392]	valid_0's multi_logloss: 0.775243
# [393]	valid_0's multi_logloss: 0.775113
# [394]	valid_0's multi_logloss: 0.774984
# [395]	valid_0's multi_logloss: 0.774858
# [396]	valid_0's multi_logloss: 0.774705
# [397]	valid_0's multi_logloss: 0.774622
# [398]	valid_0's multi_logloss: 0.774467
# [399]	valid_0's multi_logloss: 0.774438
# [400]	valid_0's multi_logloss: 0.774298
# [401]	valid_0's multi_logloss: 0.774222
# [402]	valid_0's multi_logloss: 0.774089
# [403]	valid_0's multi_logloss: 0.773969
# [404]	valid_0's multi_logloss: 0.773947
# [405]	valid_0's multi_logloss: 0.773857
# [406]	valid_0's multi_logloss: 0.77371
# [407]	valid_0's multi_logloss: 0.773643
# [408]	valid_0's multi_logloss: 0.773526
# [409]	valid_0's multi_logloss: 0.773488
# [410]	valid_0's multi_logloss: 0.773438
# [411]	valid_0's multi_logloss: 0.77326
# [412]	valid_0's multi_logloss: 0.773147
# [413]	valid_0's multi_logloss: 0.772973
# [414]	valid_0's multi_logloss: 0.772837
# [415]	valid_0's multi_logloss: 0.772727
# [416]	valid_0's multi_logloss: 0.772637
# [417]	valid_0's multi_logloss: 0.772551
# [418]	valid_0's multi_logloss: 0.772405
# [419]	valid_0's multi_logloss: 0.772264
# [420]	valid_0's multi_logloss: 0.772157
# [421]	valid_0's multi_logloss: 0.772066
# [422]	valid_0's multi_logloss: 0.771884
# [423]	valid_0's multi_logloss: 0.771743
# [424]	valid_0's multi_logloss: 0.771695
# [425]	valid_0's multi_logloss: 0.771638
# [426]	valid_0's multi_logloss: 0.771499
# [427]	valid_0's multi_logloss: 0.771197
# [428]	valid_0's multi_logloss: 0.771143
# [429]	valid_0's multi_logloss: 0.77106
# [430]	valid_0's multi_logloss: 0.770921
# [431]	valid_0's multi_logloss: 0.770897
# [432]	valid_0's multi_logloss: 0.77083
# [433]	valid_0's multi_logloss: 0.770746
# [434]	valid_0's multi_logloss: 0.770631
# [435]	valid_0's multi_logloss: 0.770556
# [436]	valid_0's multi_logloss: 0.770526
# [437]	valid_0's multi_logloss: 0.770582
# [438]	valid_0's multi_logloss: 0.77051
# [439]	valid_0's multi_logloss: 0.770404
# [440]	valid_0's multi_logloss: 0.770291
# [441]	valid_0's multi_logloss: 0.770179
# [442]	valid_0's multi_logloss: 0.770057
# [443]	valid_0's multi_logloss: 0.770013
# [444]	valid_0's multi_logloss: 0.769935
# [445]	valid_0's multi_logloss: 0.769822
# [446]	valid_0's multi_logloss: 0.769789
# [447]	valid_0's multi_logloss: 0.769755
# [448]	valid_0's multi_logloss: 0.769672
# [449]	valid_0's multi_logloss: 0.769677
# [450]	valid_0's multi_logloss: 0.76964
# [451]	valid_0's multi_logloss: 0.769652
# [452]	valid_0's multi_logloss: 0.769524
# [453]	valid_0's multi_logloss: 0.769336
# [454]	valid_0's multi_logloss: 0.769263
# [455]	valid_0's multi_logloss: 0.769302
# [456]	valid_0's multi_logloss: 0.769281
# [457]	valid_0's multi_logloss: 0.769226
# [458]	valid_0's multi_logloss: 0.769138
# [459]	valid_0's multi_logloss: 0.769008
# [460]	valid_0's multi_logloss: 0.768872
# [461]	valid_0's multi_logloss: 0.768835
# [462]	valid_0's multi_logloss: 0.768792
# [463]	valid_0's multi_logloss: 0.768816
# [464]	valid_0's multi_logloss: 0.768603
# [465]	valid_0's multi_logloss: 0.76859
# [466]	valid_0's multi_logloss: 0.768503
# [467]	valid_0's multi_logloss: 0.768598
# [468]	valid_0's multi_logloss: 0.76862
# [469]	valid_0's multi_logloss: 0.768563
# [470]	valid_0's multi_logloss: 0.768409
# [471]	valid_0's multi_logloss: 0.76828
# [472]	valid_0's multi_logloss: 0.768164
# [473]	valid_0's multi_logloss: 0.768087
# [474]	valid_0's multi_logloss: 0.767939
# [475]	valid_0's multi_logloss: 0.767854
# [476]	valid_0's multi_logloss: 0.767732
# [477]	valid_0's multi_logloss: 0.767656
# [478]	valid_0's multi_logloss: 0.767651
# [479]	valid_0's multi_logloss: 0.767668
# [480]	valid_0's multi_logloss: 0.76761
# [481]	valid_0's multi_logloss: 0.767566
# [482]	valid_0's multi_logloss: 0.767464
# [483]	valid_0's multi_logloss: 0.767449
# [484]	valid_0's multi_logloss: 0.767378
# [485]	valid_0's multi_logloss: 0.76733
# [486]	valid_0's multi_logloss: 0.76725
# [487]	valid_0's multi_logloss: 0.767213
# [488]	valid_0's multi_logloss: 0.767128
# [489]	valid_0's multi_logloss: 0.767034
# [490]	valid_0's multi_logloss: 0.767003
# [491]	valid_0's multi_logloss: 0.766928
# [492]	valid_0's multi_logloss: 0.766861
# [493]	valid_0's multi_logloss: 0.766845
# [494]	valid_0's multi_logloss: 0.766815
# [495]	valid_0's multi_logloss: 0.766779
# [496]	valid_0's multi_logloss: 0.766685
# [497]	valid_0's multi_logloss: 0.766593
# [498]	valid_0's multi_logloss: 0.766473
# [499]	valid_0's multi_logloss: 0.766352
# [500]	valid_0's multi_logloss: 0.766303
# [501]	valid_0's multi_logloss: 0.766255
# [502]	valid_0's multi_logloss: 0.76619
# [503]	valid_0's multi_logloss: 0.766113
# [504]	valid_0's multi_logloss: 0.766047
# [505]	valid_0's multi_logloss: 0.765991
# [506]	valid_0's multi_logloss: 0.766021
# [507]	valid_0's multi_logloss: 0.766015
# [508]	valid_0's multi_logloss: 0.766038
# [509]	valid_0's multi_logloss: 0.766001
# [510]	valid_0's multi_logloss: 0.765876
# [511]	valid_0's multi_logloss: 0.765854
# [512]	valid_0's multi_logloss: 0.765731
# [513]	valid_0's multi_logloss: 0.765719
# [514]	valid_0's multi_logloss: 0.765625
# [515]	valid_0's multi_logloss: 0.765619
# [516]	valid_0's multi_logloss: 0.765678
# [517]	valid_0's multi_logloss: 0.765604
# [518]	valid_0's multi_logloss: 0.765549
# [519]	valid_0's multi_logloss: 0.765581
# [520]	valid_0's multi_logloss: 0.765538
# [521]	valid_0's multi_logloss: 0.765414
# [522]	valid_0's multi_logloss: 0.765263
# [523]	valid_0's multi_logloss: 0.765283
# [524]	valid_0's multi_logloss: 0.765209
# [525]	valid_0's multi_logloss: 0.765214
# [526]	valid_0's multi_logloss: 0.76516
# [527]	valid_0's multi_logloss: 0.765152
# [528]	valid_0's multi_logloss: 0.765007
# [529]	valid_0's multi_logloss: 0.764976
# [530]	valid_0's multi_logloss: 0.764999
# [531]	valid_0's multi_logloss: 0.764879
# [532]	valid_0's multi_logloss: 0.764814
# [533]	valid_0's multi_logloss: 0.764836
# [534]	valid_0's multi_logloss: 0.764733
# [535]	valid_0's multi_logloss: 0.764724
# [536]	valid_0's multi_logloss: 0.764699
# [537]	valid_0's multi_logloss: 0.764649
# [538]	valid_0's multi_logloss: 0.764649
# [539]	valid_0's multi_logloss: 0.764624
# [540]	valid_0's multi_logloss: 0.764611
# [541]	valid_0's multi_logloss: 0.764541
# [542]	valid_0's multi_logloss: 0.76445
# [543]	valid_0's multi_logloss: 0.764372
# [544]	valid_0's multi_logloss: 0.764407
# [545]	valid_0's multi_logloss: 0.764304
# [546]	valid_0's multi_logloss: 0.764341
# [547]	valid_0's multi_logloss: 0.764295
# [548]	valid_0's multi_logloss: 0.764237
# [549]	valid_0's multi_logloss: 0.764168
# [550]	valid_0's multi_logloss: 0.764196
# [551]	valid_0's multi_logloss: 0.764159
# [552]	valid_0's multi_logloss: 0.764181
# [553]	valid_0's multi_logloss: 0.764093
# [554]	valid_0's multi_logloss: 0.763988
# [555]	valid_0's multi_logloss: 0.763816
# [556]	valid_0's multi_logloss: 0.76373
# [557]	valid_0's multi_logloss: 0.763698
# [558]	valid_0's multi_logloss: 0.763688
# [559]	valid_0's multi_logloss: 0.763807
# [560]	valid_0's multi_logloss: 0.763672
# [561]	valid_0's multi_logloss: 0.76356
# [562]	valid_0's multi_logloss: 0.763537
# [563]	valid_0's multi_logloss: 0.763705
# [564]	valid_0's multi_logloss: 0.763709
# [565]	valid_0's multi_logloss: 0.763632
# [566]	valid_0's multi_logloss: 0.763658
# [567]	valid_0's multi_logloss: 0.763604
# [568]	valid_0's multi_logloss: 0.763562
# [569]	valid_0's multi_logloss: 0.763547
# [570]	valid_0's multi_logloss: 0.763517
# [571]	valid_0's multi_logloss: 0.763512
# [572]	valid_0's multi_logloss: 0.763423
# [573]	valid_0's multi_logloss: 0.763402
# [574]	valid_0's multi_logloss: 0.763397
# [575]	valid_0's multi_logloss: 0.763365
# [576]	valid_0's multi_logloss: 0.763295
# [577]	valid_0's multi_logloss: 0.763315
# [578]	valid_0's multi_logloss: 0.763281
# [579]	valid_0's multi_logloss: 0.7632
# [580]	valid_0's multi_logloss: 0.763216
# [581]	valid_0's multi_logloss: 0.763172
# [582]	valid_0's multi_logloss: 0.763163
# [583]	valid_0's multi_logloss: 0.763009
# [584]	valid_0's multi_logloss: 0.763031
# [585]	valid_0's multi_logloss: 0.762968
# [586]	valid_0's multi_logloss: 0.762912
# [587]	valid_0's multi_logloss: 0.762967
# [588]	valid_0's multi_logloss: 0.762887
# [589]	valid_0's multi_logloss: 0.762804
# [590]	valid_0's multi_logloss: 0.76274
# [591]	valid_0's multi_logloss: 0.762656
# [592]	valid_0's multi_logloss: 0.762623
# [593]	valid_0's multi_logloss: 0.762601
# [594]	valid_0's multi_logloss: 0.762559
# [595]	valid_0's multi_logloss: 0.762468
# [596]	valid_0's multi_logloss: 0.762368
# [597]	valid_0's multi_logloss: 0.762324
# [598]	valid_0's multi_logloss: 0.762304
# [599]	valid_0's multi_logloss: 0.762233
# [600]	valid_0's multi_logloss: 0.762196
# [601]	valid_0's multi_logloss: 0.762193
# [602]	valid_0's multi_logloss: 0.762069
# [603]	valid_0's multi_logloss: 0.762024
# [604]	valid_0's multi_logloss: 0.761981
# [605]	valid_0's multi_logloss: 0.761962
# [606]	valid_0's multi_logloss: 0.762033
# [607]	valid_0's multi_logloss: 0.761979
# [608]	valid_0's multi_logloss: 0.761854
# [609]	valid_0's multi_logloss: 0.761758
# [610]	valid_0's multi_logloss: 0.761676
# [611]	valid_0's multi_logloss: 0.761803
# [612]	valid_0's multi_logloss: 0.761691
# [613]	valid_0's multi_logloss: 0.761682
# [614]	valid_0's multi_logloss: 0.761646
# [615]	valid_0's multi_logloss: 0.761603
# [616]	valid_0's multi_logloss: 0.761585
# [617]	valid_0's multi_logloss: 0.761589
# [618]	valid_0's multi_logloss: 0.761523
# [619]	valid_0's multi_logloss: 0.761539
# [620]	valid_0's multi_logloss: 0.761569
# [621]	valid_0's multi_logloss: 0.761581
# [622]	valid_0's multi_logloss: 0.76152
# [623]	valid_0's multi_logloss: 0.761452
# [624]	valid_0's multi_logloss: 0.761359
# [625]	valid_0's multi_logloss: 0.761358
# [626]	valid_0's multi_logloss: 0.761316
# [627]	valid_0's multi_logloss: 0.761251
# [628]	valid_0's multi_logloss: 0.761231
# [629]	valid_0's multi_logloss: 0.76123
# [630]	valid_0's multi_logloss: 0.761198
# [631]	valid_0's multi_logloss: 0.761157
# [632]	valid_0's multi_logloss: 0.76103
# [633]	valid_0's multi_logloss: 0.760979
# [634]	valid_0's multi_logloss: 0.760865
# [635]	valid_0's multi_logloss: 0.760887
# [636]	valid_0's multi_logloss: 0.760897
# [637]	valid_0's multi_logloss: 0.760834
# [638]	valid_0's multi_logloss: 0.760807
# [639]	valid_0's multi_logloss: 0.760703
# [640]	valid_0's multi_logloss: 0.760578
# [641]	valid_0's multi_logloss: 0.760577
# [642]	valid_0's multi_logloss: 0.760625
# [643]	valid_0's multi_logloss: 0.760586
# [644]	valid_0's multi_logloss: 0.760536
# [645]	valid_0's multi_logloss: 0.760452
# [646]	valid_0's multi_logloss: 0.76045
# [647]	valid_0's multi_logloss: 0.760628
# [648]	valid_0's multi_logloss: 0.760607
# [649]	valid_0's multi_logloss: 0.760594
# [650]	valid_0's multi_logloss: 0.76055
# [651]	valid_0's multi_logloss: 0.760487
# [652]	valid_0's multi_logloss: 0.760413
# [653]	valid_0's multi_logloss: 0.760376
# [654]	valid_0's multi_logloss: 0.760386
# [655]	valid_0's multi_logloss: 0.760355
# [656]	valid_0's multi_logloss: 0.760356
# [657]	valid_0's multi_logloss: 0.76031
# [658]	valid_0's multi_logloss: 0.760295
# [659]	valid_0's multi_logloss: 0.760293
# [660]	valid_0's multi_logloss: 0.760319
# [661]	valid_0's multi_logloss: 0.760336
# [662]	valid_0's multi_logloss: 0.760199
# [663]	valid_0's multi_logloss: 0.760202
# [664]	valid_0's multi_logloss: 0.760142
# [665]	valid_0's multi_logloss: 0.760077
# [666]	valid_0's multi_logloss: 0.760143
# [667]	valid_0's multi_logloss: 0.760148
# [668]	valid_0's multi_logloss: 0.760073
# [669]	valid_0's multi_logloss: 0.760075
# [670]	valid_0's multi_logloss: 0.76002
# [671]	valid_0's multi_logloss: 0.759933
# [672]	valid_0's multi_logloss: 0.759905
# [673]	valid_0's multi_logloss: 0.759819
# [674]	valid_0's multi_logloss: 0.759807
# [675]	valid_0's multi_logloss: 0.759748
# [676]	valid_0's multi_logloss: 0.759729
# [677]	valid_0's multi_logloss: 0.759664
# [678]	valid_0's multi_logloss: 0.759598
# [679]	valid_0's multi_logloss: 0.759559
# [680]	valid_0's multi_logloss: 0.759501
# [681]	valid_0's multi_logloss: 0.759412
# [682]	valid_0's multi_logloss: 0.759432
# [683]	valid_0's multi_logloss: 0.759411
# [684]	valid_0's multi_logloss: 0.759303
# [685]	valid_0's multi_logloss: 0.759242
# [686]	valid_0's multi_logloss: 0.759259
# [687]	valid_0's multi_logloss: 0.75924
# [688]	valid_0's multi_logloss: 0.759191
# [689]	valid_0's multi_logloss: 0.759229
# [690]	valid_0's multi_logloss: 0.759237
# [691]	valid_0's multi_logloss: 0.759226
# [692]	valid_0's multi_logloss: 0.759216
# [693]	valid_0's multi_logloss: 0.759251
# [694]	valid_0's multi_logloss: 0.759232
# [695]	valid_0's multi_logloss: 0.759259
# [696]	valid_0's multi_logloss: 0.759138
# [697]	valid_0's multi_logloss: 0.759069
# [698]	valid_0's multi_logloss: 0.759096
# [699]	valid_0's multi_logloss: 0.759043
# [700]	valid_0's multi_logloss: 0.75906
# [701]	valid_0's multi_logloss: 0.759035
# [702]	valid_0's multi_logloss: 0.759077
# [703]	valid_0's multi_logloss: 0.759137
# [704]	valid_0's multi_logloss: 0.75912
# [705]	valid_0's multi_logloss: 0.759143
# [706]	valid_0's multi_logloss: 0.759132
# [707]	valid_0's multi_logloss: 0.759122
# [708]	valid_0's multi_logloss: 0.759105
# [709]	valid_0's multi_logloss: 0.759081
# [710]	valid_0's multi_logloss: 0.759012
# [711]	valid_0's multi_logloss: 0.758941
# [712]	valid_0's multi_logloss: 0.758905
# [713]	valid_0's multi_logloss: 0.758893
# [714]	valid_0's multi_logloss: 0.75894
# [715]	valid_0's multi_logloss: 0.758883
# [716]	valid_0's multi_logloss: 0.758808
# [717]	valid_0's multi_logloss: 0.758819
# [718]	valid_0's multi_logloss: 0.758772
# [719]	valid_0's multi_logloss: 0.758793
# [720]	valid_0's multi_logloss: 0.758779
# [721]	valid_0's multi_logloss: 0.758834
# [722]	valid_0's multi_logloss: 0.758832
# [723]	valid_0's multi_logloss: 0.758853
# [724]	valid_0's multi_logloss: 0.758756
# [725]	valid_0's multi_logloss: 0.758678
# [726]	valid_0's multi_logloss: 0.758658
# [727]	valid_0's multi_logloss: 0.75868
# [728]	valid_0's multi_logloss: 0.758689
# [729]	valid_0's multi_logloss: 0.758764
# [730]	valid_0's multi_logloss: 0.758675
# [731]	valid_0's multi_logloss: 0.758686
# [732]	valid_0's multi_logloss: 0.758694
# [733]	valid_0's multi_logloss: 0.758728
# [734]	valid_0's multi_logloss: 0.758735
# [735]	valid_0's multi_logloss: 0.75872
# [736]	valid_0's multi_logloss: 0.758658
# [737]	valid_0's multi_logloss: 0.758592
# [738]	valid_0's multi_logloss: 0.758608
# [739]	valid_0's multi_logloss: 0.758627
# [740]	valid_0's multi_logloss: 0.758568
# [741]	valid_0's multi_logloss: 0.758502
# [742]	valid_0's multi_logloss: 0.758501
# [743]	valid_0's multi_logloss: 0.758499
# [744]	valid_0's multi_logloss: 0.758575
# [745]	valid_0's multi_logloss: 0.758493
# [746]	valid_0's multi_logloss: 0.758486
# [747]	valid_0's multi_logloss: 0.758485
# [748]	valid_0's multi_logloss: 0.758463
# [749]	valid_0's multi_logloss: 0.75841
# [750]	valid_0's multi_logloss: 0.758498
# [751]	valid_0's multi_logloss: 0.758491
# [752]	valid_0's multi_logloss: 0.758503
# [753]	valid_0's multi_logloss: 0.758543
# [754]	valid_0's multi_logloss: 0.758527
# [755]	valid_0's multi_logloss: 0.758466
# [756]	valid_0's multi_logloss: 0.758395
# [757]	valid_0's multi_logloss: 0.758466
# [758]	valid_0's multi_logloss: 0.75839
# [759]	valid_0's multi_logloss: 0.758335
# [760]	valid_0's multi_logloss: 0.758351
# [761]	valid_0's multi_logloss: 0.758314
# [762]	valid_0's multi_logloss: 0.758323
# [763]	valid_0's multi_logloss: 0.758358
# [764]	valid_0's multi_logloss: 0.758308
# [765]	valid_0's multi_logloss: 0.758317
# [766]	valid_0's multi_logloss: 0.758351
# [767]	valid_0's multi_logloss: 0.75837
# [768]	valid_0's multi_logloss: 0.758367
# [769]	valid_0's multi_logloss: 0.758273
# [770]	valid_0's multi_logloss: 0.758243
# [771]	valid_0's multi_logloss: 0.758333
# [772]	valid_0's multi_logloss: 0.758342
# [773]	valid_0's multi_logloss: 0.758306
# [774]	valid_0's multi_logloss: 0.758396
# [775]	valid_0's multi_logloss: 0.758355
# [776]	valid_0's multi_logloss: 0.758355
# [777]	valid_0's multi_logloss: 0.758369
# [778]	valid_0's multi_logloss: 0.758289
# [779]	valid_0's multi_logloss: 0.758265
# [780]	valid_0's multi_logloss: 0.758309
# [781]	valid_0's multi_logloss: 0.758328
# [782]	valid_0's multi_logloss: 0.758307
# [783]	valid_0's multi_logloss: 0.758341
# [784]	valid_0's multi_logloss: 0.758365
# [785]	valid_0's multi_logloss: 0.758367
# [786]	valid_0's multi_logloss: 0.758294
# [787]	valid_0's multi_logloss: 0.758263
# [788]	valid_0's multi_logloss: 0.758201
# [789]	valid_0's multi_logloss: 0.758198
# [790]	valid_0's multi_logloss: 0.758214
# [791]	valid_0's multi_logloss: 0.758273
# [792]	valid_0's multi_logloss: 0.758242
# [793]	valid_0's multi_logloss: 0.758188
# [794]	valid_0's multi_logloss: 0.758201
# [795]	valid_0's multi_logloss: 0.758213
# [796]	valid_0's multi_logloss: 0.758232
# [797]	valid_0's multi_logloss: 0.758287
# [798]	valid_0's multi_logloss: 0.758219
# [799]	valid_0's multi_logloss: 0.758198
# [800]	valid_0's multi_logloss: 0.758209
# [801]	valid_0's multi_logloss: 0.758193
# [802]	valid_0's multi_logloss: 0.758255
# [803]	valid_0's multi_logloss: 0.758235
# [804]	valid_0's multi_logloss: 0.758285
# [805]	valid_0's multi_logloss: 0.758261
# [806]	valid_0's multi_logloss: 0.758359
# [807]	valid_0's multi_logloss: 0.758376
# [808]	valid_0's multi_logloss: 0.758328
# [809]	valid_0's multi_logloss: 0.758313
# [810]	valid_0's multi_logloss: 0.75833
# [811]	valid_0's multi_logloss: 0.758302
# [812]	valid_0's multi_logloss: 0.758248
# [813]	valid_0's multi_logloss: 0.758255
# [814]	valid_0's multi_logloss: 0.758295
# [815]	valid_0's multi_logloss: 0.758345
# [816]	valid_0's multi_logloss: 0.758393
# [817]	valid_0's multi_logloss: 0.75838
# [818]	valid_0's multi_logloss: 0.758365
# [819]	valid_0's multi_logloss: 0.758381
# [820]	valid_0's multi_logloss: 0.75837
# [821]	valid_0's multi_logloss: 0.758463
# [822]	valid_0's multi_logloss: 0.758494
# [823]	valid_0's multi_logloss: 0.758573
# [824]	valid_0's multi_logloss: 0.758624
# [825]	valid_0's multi_logloss: 0.758601
# [826]	valid_0's multi_logloss: 0.758594
# [827]	valid_0's multi_logloss: 0.758574
# [828]	valid_0's multi_logloss: 0.758543
# [829]	valid_0's multi_logloss: 0.758535
# [830]	valid_0's multi_logloss: 0.758556
# [831]	valid_0's multi_logloss: 0.758544
# [832]	valid_0's multi_logloss: 0.758494
# [833]	valid_0's multi_logloss: 0.758499
# [834]	valid_0's multi_logloss: 0.758493
# [835]	valid_0's multi_logloss: 0.758506
# [836]	valid_0's multi_logloss: 0.758514
# [837]	valid_0's multi_logloss: 0.758539
# [838]	valid_0's multi_logloss: 0.758538
# [839]	valid_0's multi_logloss: 0.758497
# [840]	valid_0's multi_logloss: 0.75857
# [841]	valid_0's multi_logloss: 0.758507
# [842]	valid_0's multi_logloss: 0.758563
# [843]	valid_0's multi_logloss: 0.758522
# [844]	valid_0's multi_logloss: 0.758569
# [845]	valid_0's multi_logloss: 0.75854
# [846]	valid_0's multi_logloss: 0.758563
# [847]	valid_0's multi_logloss: 0.758486
# [848]	valid_0's multi_logloss: 0.758462
# [849]	valid_0's multi_logloss: 0.758432
# [850]	valid_0's multi_logloss: 0.758464
# [851]	valid_0's multi_logloss: 0.758494
# [852]	valid_0's multi_logloss: 0.758479
# [853]	valid_0's multi_logloss: 0.75843
# [854]	valid_0's multi_logloss: 0.758406
# [855]	valid_0's multi_logloss: 0.758482
# [856]	valid_0's multi_logloss: 0.75843
# [857]	valid_0's multi_logloss: 0.758339
# [858]	valid_0's multi_logloss: 0.758328
# [859]	valid_0's multi_logloss: 0.758387
# [860]	valid_0's multi_logloss: 0.758377
# [861]	valid_0's multi_logloss: 0.758376
# [862]	valid_0's multi_logloss: 0.758442
# [863]	valid_0's multi_logloss: 0.758414
# [864]	valid_0's multi_logloss: 0.7584
# [865]	valid_0's multi_logloss: 0.758395
# [866]	valid_0's multi_logloss: 0.758487
# [867]	valid_0's multi_logloss: 0.758471
# [868]	valid_0's multi_logloss: 0.758478
# [869]	valid_0's multi_logloss: 0.758398
# [870]	valid_0's multi_logloss: 0.758479
# [871]	valid_0's multi_logloss: 0.758569
# [872]	valid_0's multi_logloss: 0.758544
# [873]	valid_0's multi_logloss: 0.7585
# [874]	valid_0's multi_logloss: 0.758549
# [875]	valid_0's multi_logloss: 0.758535
# [876]	valid_0's multi_logloss: 0.758526
# [877]	valid_0's multi_logloss: 0.758549
# [878]	valid_0's multi_logloss: 0.758531
# [879]	valid_0's multi_logloss: 0.758534
# [880]	valid_0's multi_logloss: 0.758489
# [881]	valid_0's multi_logloss: 0.758534
# [882]	valid_0's multi_logloss: 0.758483
# [883]	valid_0's multi_logloss: 0.758462
# [884]	valid_0's multi_logloss: 0.758512
# [885]	valid_0's multi_logloss: 0.758558
# [886]	valid_0's multi_logloss: 0.758501
# [887]	valid_0's multi_logloss: 0.758583
# [888]	valid_0's multi_logloss: 0.758533
# [889]	valid_0's multi_logloss: 0.758521
# [890]	valid_0's multi_logloss: 0.758565
# [891]	valid_0's multi_logloss: 0.758554
# [892]	valid_0's multi_logloss: 0.758585
# [893]	valid_0's multi_logloss: 0.758629
# Early stopping, best iteration is:
# [793]	valid_0's multi_logloss: 0.758188

# %%
y_true=y_test
y_pred=gbm.predict(X_test,num_iteration=793)
y=[]
for i in range(len(y_pred)):
    y_pred[i][0]=y_pred[i][0]
    y_pred[i][1]=y_pred[i][1]
    y_pred[i][3]=y_pred[i][3]
    y_pred[i][4]=y_pred[i][4]
    max_value=max(y_pred[i])
    for j in range(len(y_pred[i])):
        if max_value==y_pred[i][j]:
            y.append(j)
                
target_names = ['class 0', 'class 1', 'class 2','class 3','class 4']
print(classification_report(y_true,y,target_names = target_names ))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-205-e4098355d7f0> in <module>()
#      13
#      14 target_names = ['class 0', 'class 1', 'class 2','class 3','class 4']
# ---> 15 print(classification_report(y_true,y,target_names = target_names ))
#
# d:\python\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict)
#    1850     """
#    1851
# -> 1852     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1853
#    1854     labels_given = True
#
# d:\python\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# d:\python\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [406, 1]

# %%
import xgboost as xgb
params = {
            'booster':'gbtree',
            'objective':'binary:logistic',
            'eta':0.1,
            'max_depth':10,
            'subsample':1.0,
            'min_child_weight':5,
            'colsample_bytree':0.2,
            'scale_pos_weight':0.1,
            'eval_metric':'auc',
            'gamma':0.2,           
            'lambda':300
}
#xgb_train = xgb.Dataset(X_train, y_train) 
#xgb_eval = xgb.Dataset(X_test, y_test, reference=lgb_train)
xgclf = xgb.train(params, X_train,y_train,num_boost_round=2000,
        metrics='auc', early_stopping_rounds=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-c69f69fedc83> in <module>()
#      16 #xgb_eval = xgb.Dataset(X_test, y_test, reference=lgb_train)
#      17 xgclf = xgb.train(params, X_train,y_train,num_boost_round=2000,
# ---> 18         metrics='auc', early_stopping_rounds=100)
#
# TypeError: train() got multiple values for argument 'num_boost_round'

# %%
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['figure.figsize'] = (20.0, 20.0) # 显示大小
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['figure.dpi'] = 100
lgb.plot_importance(gbm,ignore_zero=False)
#plt.savefig('./test2.jpg')
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")
from gcforest.gcforest import *
import pandas as pd
from numpy import sort
import xgboost as xgb
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMClassifier

#%%
def get_toy_config():
    config = {}
    ca_config = {}
    ca_config["random_state"] = 0
    ca_config["max_layers"] = 100
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 5
    ca_config["estimators"] = []

    ca_config["estimators"].append({"n_folds": 5, "type": 0, "n_estimators": 400,'num_leaves':10,
     'max_depth':4,
     'subsample':0.8,
     'colsample_bytree':0.8,
     'max_bin':10000,'min_data_in_leaf':10,
     'feature_fraction': 0.7,'lambda_l1':2,
     'lambda_l2': 2,
     'objective': 'multiclass', "silent": True, "nthread": -1, "learning_rate": 0.01})
    ca_config["estimators"].append({"n_folds": 5, 'min_data_in_leaf':10,'num_leaves':12,"type": "XGBClassifier", "n_estimators": 400, "max_depth": 4,"objective": "multiclass",'num_class':5, "silent": True, "nthread": -1, "learning_rate": 0.01})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "n_estimators": 20, "max_depth":4, "n_jobs": -1})
    ca_config["estimators"].append({"n_folds": 5, "type": "ExtraTreesClassifier", "n_estimators": 30, "max_depth": 4, "n_jobs": -1})
    
    config['silent']=True
    config["cascade"] = ca_config
    config["window"] = 16
    config["stride"] = 2
    return config


# %%
def get_Xy(csv_f):
    X = csv_f.drop(['本期内是否理赔'], axis=1)
    y = csv_f['本期内是否理赔']
    return X, y


#%%
conf = get_toy_config()
gc = GCForest(conf)  # should be a dict
X_train_enc = gc.fit_transform(X_train.as_matrix(), y_train.as_matrix())
#pre_y = gc.predict(X_test.as_matrix())

#%%
#print(classification_report(y_test, pre_y))
#prec = precision_score(test_y, pre_y)
#print("Test Precision of GcForest = {:.2f} %".format(prec * 100))
# Out:
# [ 2019-09-05 22:08:36,316][cascade_classifier.fit_transform] X_groups_train.shape=[(1725, 22)],y_train.shape=(1725,),X_groups_test.shape=no_test,y_test.shape=no_test
# [ 2019-09-05 22:08:36,324][cascade_classifier.fit_transform] group_dims=[22]
# [ 2019-09-05 22:08:36,330][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-09-05 22:08:36,337][cascade_classifier.fit_transform] group_ends=[22]
# [ 2019-09-05 22:08:36,343][cascade_classifier.fit_transform] X_train.shape=(1725, 22),X_test.shape=(0, 22)
# [ 2019-09-05 22:08:36,351][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(1725, 22), X_cur_test.shape=(0, 22)
# [ 2019-09-05 22:08:40,897][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 5_folds.train_0.predict)=58.67%
# [ 2019-09-05 22:08:43,148][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 5_folds.train_1.predict)=55.78%
# [ 2019-09-05 22:08:45,083][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 5_folds.train_2.predict)=54.20%
# [ 2019-09-05 22:08:47,160][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 5_folds.train_3.predict)=56.23%
# [ 2019-09-05 22:08:49,285][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 5_folds.train_4.predict)=56.56%
# [ 2019-09-05 22:08:49,288][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_0 - 5_folds.train_cv.predict)=56.29%
# [ 2019-09-05 22:08:54,080][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_1 - 5_folds.train_0.predict)=58.38%
# [ 2019-09-05 22:08:58,189][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_1 - 5_folds.train_1.predict)=58.09%
# [ 2019-09-05 22:09:02,507][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_1 - 5_folds.train_2.predict)=58.26%
# [ 2019-09-05 22:09:07,319][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_1 - 5_folds.train_3.predict)=54.20%
# [ 2019-09-05 22:09:12,509][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_1 - 5_folds.train_4.predict)=56.85%
# [ 2019-09-05 22:09:12,512][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_1 - 5_folds.train_cv.predict)=57.16%
# [ 2019-09-05 22:09:12,752][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_2 - 5_folds.train_0.predict)=53.76%
# [ 2019-09-05 22:09:12,984][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_2 - 5_folds.train_1.predict)=49.71%
# [ 2019-09-05 22:09:13,268][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_2 - 5_folds.train_2.predict)=50.72%
# [ 2019-09-05 22:09:13,636][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_2 - 5_folds.train_3.predict)=52.46%
# [ 2019-09-05 22:09:13,964][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_2 - 5_folds.train_4.predict)=55.10%
# [ 2019-09-05 22:09:13,968][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_2 - 5_folds.train_cv.predict)=52.35%
# [ 2019-09-05 22:09:14,250][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_3 - 5_folds.train_0.predict)=54.34%
# [ 2019-09-05 22:09:14,527][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_3 - 5_folds.train_1.predict)=52.89%
# [ 2019-09-05 22:09:14,974][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_3 - 5_folds.train_2.predict)=54.78%
# [ 2019-09-05 22:09:15,521][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_3 - 5_folds.train_3.predict)=51.88%
# [ 2019-09-05 22:09:16,025][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_3 - 5_folds.train_4.predict)=54.23%
# [ 2019-09-05 22:09:16,031][kfold_wrapper.log_eval_metrics] Accuracy(layer_0 - estimator_3 - 5_folds.train_cv.predict)=53.62%
# [ 2019-09-05 22:09:16,040][cascade_classifier.calc_accuracy] Accuracy(layer_0 - train.classifier_average)=56.87%
# [ 2019-09-05 22:09:16,044][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(1725, 42), X_cur_test.shape=(0, 42)
# [ 2019-09-05 22:09:22,149][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 5_folds.train_0.predict)=57.80%
# [ 2019-09-05 22:09:26,283][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 5_folds.train_1.predict)=57.80%
# [ 2019-09-05 22:09:30,929][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 5_folds.train_2.predict)=59.13%
# [ 2019-09-05 22:09:36,603][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 5_folds.train_3.predict)=59.13%
# [ 2019-09-05 22:09:44,437][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 5_folds.train_4.predict)=55.69%
# [ 2019-09-05 22:09:44,440][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_0 - 5_folds.train_cv.predict)=57.91%
# [ 2019-09-05 22:09:53,512][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_1 - 5_folds.train_0.predict)=56.07%
# [ 2019-09-05 22:10:02,962][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_1 - 5_folds.train_1.predict)=54.05%
# [ 2019-09-05 22:10:15,836][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_1 - 5_folds.train_2.predict)=56.52%
# [ 2019-09-05 22:10:25,340][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_1 - 5_folds.train_3.predict)=58.55%
# [ 2019-09-05 22:10:37,347][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_1 - 5_folds.train_4.predict)=52.48%
# [ 2019-09-05 22:10:37,354][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_1 - 5_folds.train_cv.predict)=55.54%
# [ 2019-09-05 22:10:37,610][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_2 - 5_folds.train_0.predict)=58.38%
# [ 2019-09-05 22:10:37,899][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_2 - 5_folds.train_1.predict)=58.96%
# [ 2019-09-05 22:10:38,247][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_2 - 5_folds.train_2.predict)=54.78%
# [ 2019-09-05 22:10:38,573][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_2 - 5_folds.train_3.predict)=55.65%
# [ 2019-09-05 22:10:38,823][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_2 - 5_folds.train_4.predict)=54.81%
# [ 2019-09-05 22:10:38,826][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_2 - 5_folds.train_cv.predict)=56.52%
# [ 2019-09-05 22:10:39,080][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_3 - 5_folds.train_0.predict)=56.94%
# [ 2019-09-05 22:10:39,332][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_3 - 5_folds.train_1.predict)=55.49%
# [ 2019-09-05 22:10:39,594][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_3 - 5_folds.train_2.predict)=56.81%
# [ 2019-09-05 22:10:39,916][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_3 - 5_folds.train_3.predict)=57.68%
# [ 2019-09-05 22:10:40,593][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_3 - 5_folds.train_4.predict)=54.23%
# [ 2019-09-05 22:10:40,596][kfold_wrapper.log_eval_metrics] Accuracy(layer_1 - estimator_3 - 5_folds.train_cv.predict)=56.23%
# [ 2019-09-05 22:10:40,599][cascade_classifier.calc_accuracy] Accuracy(layer_1 - train.classifier_average)=57.33%
# [ 2019-09-05 22:10:40,604][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(1725, 42), X_cur_test.shape=(0, 42)
# [ 2019-09-05 22:10:47,951][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 5_folds.train_0.predict)=54.91%
# [ 2019-09-05 22:10:52,848][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 5_folds.train_1.predict)=55.20%
# [ 2019-09-05 22:10:57,107][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 5_folds.train_2.predict)=59.13%
# [ 2019-09-05 22:11:01,468][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 5_folds.train_3.predict)=52.17%
# [ 2019-09-05 22:11:05,982][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 5_folds.train_4.predict)=57.73%
# [ 2019-09-05 22:11:05,985][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_0 - 5_folds.train_cv.predict)=55.83%
# [ 2019-09-05 22:11:14,979][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_1 - 5_folds.train_0.predict)=59.54%
# [ 2019-09-05 22:11:23,945][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_1 - 5_folds.train_1.predict)=55.78%
# [ 2019-09-05 22:11:33,563][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_1 - 5_folds.train_2.predict)=58.26%
# [ 2019-09-05 22:11:43,150][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_1 - 5_folds.train_3.predict)=55.65%
# [ 2019-09-05 22:11:52,582][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_1 - 5_folds.train_4.predict)=55.69%
# [ 2019-09-05 22:11:52,585][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_1 - 5_folds.train_cv.predict)=56.99%
# [ 2019-09-05 22:11:52,824][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_2 - 5_folds.train_0.predict)=57.51%
# [ 2019-09-05 22:11:53,056][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_2 - 5_folds.train_1.predict)=55.78%
# [ 2019-09-05 22:11:53,284][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_2 - 5_folds.train_2.predict)=56.52%
# [ 2019-09-05 22:11:53,682][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_2 - 5_folds.train_3.predict)=57.68%
# [ 2019-09-05 22:11:53,989][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_2 - 5_folds.train_4.predict)=58.02%
# [ 2019-09-05 22:11:53,996][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_2 - 5_folds.train_cv.predict)=57.10%
# [ 2019-09-05 22:11:54,351][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_3 - 5_folds.train_0.predict)=56.94%
# [ 2019-09-05 22:11:54,822][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_3 - 5_folds.train_1.predict)=56.36%
# [ 2019-09-05 22:11:55,302][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_3 - 5_folds.train_2.predict)=57.68%
# [ 2019-09-05 22:11:55,586][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_3 - 5_folds.train_3.predict)=55.36%
# [ 2019-09-05 22:11:55,904][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_3 - 5_folds.train_4.predict)=56.56%
# [ 2019-09-05 22:11:55,912][kfold_wrapper.log_eval_metrics] Accuracy(layer_2 - estimator_3 - 5_folds.train_cv.predict)=56.58%
# [ 2019-09-05 22:11:55,919][cascade_classifier.calc_accuracy] Accuracy(layer_2 - train.classifier_average)=56.87%
# [ 2019-09-05 22:11:55,927][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(1725, 42), X_cur_test.shape=(0, 42)
# [ 2019-09-05 22:12:01,831][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 5_folds.train_0.predict)=53.47%
# [ 2019-09-05 22:12:06,533][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 5_folds.train_1.predict)=58.96%
# [ 2019-09-05 22:12:10,763][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 5_folds.train_2.predict)=59.13%
# [ 2019-09-05 22:12:14,794][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 5_folds.train_3.predict)=57.10%
# [ 2019-09-05 22:12:19,949][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 5_folds.train_4.predict)=57.43%
# [ 2019-09-05 22:12:19,952][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_0 - 5_folds.train_cv.predict)=57.22%
# [ 2019-09-05 22:12:28,760][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_1 - 5_folds.train_0.predict)=53.76%
# [ 2019-09-05 22:12:39,488][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_1 - 5_folds.train_1.predict)=55.49%
# [ 2019-09-05 22:12:49,362][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_1 - 5_folds.train_2.predict)=58.26%
# [ 2019-09-05 22:12:58,835][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_1 - 5_folds.train_3.predict)=57.68%
# [ 2019-09-05 22:13:09,214][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_1 - 5_folds.train_4.predict)=58.89%
# [ 2019-09-05 22:13:09,217][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_1 - 5_folds.train_cv.predict)=56.81%
# [ 2019-09-05 22:13:09,456][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_2 - 5_folds.train_0.predict)=58.38%
# [ 2019-09-05 22:13:09,691][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_2 - 5_folds.train_1.predict)=57.80%
# [ 2019-09-05 22:13:09,926][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_2 - 5_folds.train_2.predict)=55.65%
# [ 2019-09-05 22:13:10,161][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_2 - 5_folds.train_3.predict)=59.13%
# [ 2019-09-05 22:13:10,390][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_2 - 5_folds.train_4.predict)=55.98%
# [ 2019-09-05 22:13:10,393][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_2 - 5_folds.train_cv.predict)=57.39%
# [ 2019-09-05 22:13:10,621][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_3 - 5_folds.train_0.predict)=54.91%
# [ 2019-09-05 22:13:10,855][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_3 - 5_folds.train_1.predict)=55.49%
# [ 2019-09-05 22:13:11,085][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_3 - 5_folds.train_2.predict)=55.65%
# [ 2019-09-05 22:13:11,363][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_3 - 5_folds.train_3.predict)=57.39%
# [ 2019-09-05 22:13:11,675][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_3 - 5_folds.train_4.predict)=55.98%
# [ 2019-09-05 22:13:11,681][kfold_wrapper.log_eval_metrics] Accuracy(layer_3 - estimator_3 - 5_folds.train_cv.predict)=55.88%
# [ 2019-09-05 22:13:11,688][cascade_classifier.calc_accuracy] Accuracy(layer_3 - train.classifier_average)=57.22%
# [ 2019-09-05 22:13:11,696][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(1725, 42), X_cur_test.shape=(0, 42)
# [ 2019-09-05 22:13:19,038][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 5_folds.train_0.predict)=54.34%
# [ 2019-09-05 22:13:23,583][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 5_folds.train_1.predict)=54.34%
# [ 2019-09-05 22:13:28,122][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 5_folds.train_2.predict)=55.94%
# [ 2019-09-05 22:13:32,465][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 5_folds.train_3.predict)=58.26%
# [ 2019-09-05 22:13:36,626][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 5_folds.train_4.predict)=58.02%
# [ 2019-09-05 22:13:36,629][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_0 - 5_folds.train_cv.predict)=56.17%
# [ 2019-09-05 22:13:45,332][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_1 - 5_folds.train_0.predict)=53.76%
# [ 2019-09-05 22:13:54,539][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_1 - 5_folds.train_1.predict)=54.62%
# [ 2019-09-05 22:14:03,420][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_1 - 5_folds.train_2.predict)=53.04%
# [ 2019-09-05 22:14:13,448][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_1 - 5_folds.train_3.predict)=53.91%
# [ 2019-09-05 22:14:22,271][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_1 - 5_folds.train_4.predict)=53.94%
# [ 2019-09-05 22:14:22,274][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_1 - 5_folds.train_cv.predict)=53.86%
# [ 2019-09-05 22:14:22,512][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_2 - 5_folds.train_0.predict)=56.36%
# [ 2019-09-05 22:14:22,752][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_2 - 5_folds.train_1.predict)=55.49%
# [ 2019-09-05 22:14:22,999][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_2 - 5_folds.train_2.predict)=57.97%
# [ 2019-09-05 22:14:23,235][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_2 - 5_folds.train_3.predict)=56.23%
# [ 2019-09-05 22:14:23,485][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_2 - 5_folds.train_4.predict)=59.48%
# [ 2019-09-05 22:14:23,488][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_2 - 5_folds.train_cv.predict)=57.10%
# [ 2019-09-05 22:14:23,768][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_3 - 5_folds.train_0.predict)=58.67%
# [ 2019-09-05 22:14:24,232][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_3 - 5_folds.train_1.predict)=56.36%
# [ 2019-09-05 22:14:24,476][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_3 - 5_folds.train_2.predict)=56.23%
# [ 2019-09-05 22:14:24,716][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_3 - 5_folds.train_3.predict)=57.10%
# [ 2019-09-05 22:14:24,946][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_3 - 5_folds.train_4.predict)=56.27%
# [ 2019-09-05 22:14:24,949][kfold_wrapper.log_eval_metrics] Accuracy(layer_4 - estimator_3 - 5_folds.train_cv.predict)=56.93%
# [ 2019-09-05 22:14:24,951][cascade_classifier.calc_accuracy] Accuracy(layer_4 - train.classifier_average)=55.94%
# [ 2019-09-05 22:14:24,954][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=2, accuracy_train=57.33%, accuracy_test=0.00%

# %%
X_train.as_matrix().shape
# Out:
# (1725, 22)

# %%
y_pred=gc.predict_proba(X_test.as_matrix())
y_true=y_test
y=[]
for i in range(len(y_pred)):
    y_pred[i][0]=y_pred[i][0]-0.2
    y_pred[i][1]=y_pred[i][1]
    y_pred[i][3]=y_pred[i][3]
    y_pred[i][4]=y_pred[i][4]
    max_value=max(y_pred[i])
    for j in range(len(y_pred[i])):
        if max_value==y_pred[i][j]:
            y.append(j)

#print(y)
#print(y_true)
            
target_names = ['class 0', 'class 1', 'class 2','class 3','class 4']
print(classification_report(y_true,y,target_names = target_names ))
# Out:
# [ 2019-09-05 20:44:59,646][cascade_classifier.transform] X_groups_test.shape=[(406, 22)]
# [ 2019-09-05 20:44:59,652][cascade_classifier.transform] group_dims=[22]
# [ 2019-09-05 20:44:59,657][cascade_classifier.transform] X_test.shape=(406, 22)
# [ 2019-09-05 20:44:59,662][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(406, 22)
# [ 2019-09-05 20:45:02,001][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(406, 42)
#               precision    recall  f1-score   support
#
#      class 0       0.95      0.78      0.86       288
#      class 1       0.15      0.26      0.19        31
#      class 2       0.37      0.63      0.46        41
#      class 3       0.30      0.25      0.27        32
#      class 4       0.12      0.14      0.13        14
#
#     accuracy                           0.67       406
#    macro avg       0.38      0.41      0.38       406
# weighted avg       0.75      0.67      0.70       406

# %%
from sklearn.externals import joblib
joblib.dump(gc,'g_model.pkl')
#clf=joblib.load('filename.pkl')
# Out:
# ['g_model.pkl']

# %%
d.iloc[0,1:]
# Out:
# 金融信息关注程度a4002a           2.000000e+00
# 风险和汇报组合选择a4003           3.000000e+00
# 股票和基金风险更大a4007           1.000000e+00
# 银行储蓄卡数量d1103             3.000000e+00
# 活期存款余额d1105              2.000000e+04
# 定期存款总额d2104_imp          1.500000e+05
# 是否持有基金d5102              2.000000e+00
# 是否拥有银行理财产品d7102          2.000000e+00
# 去年平均每月伙食费g1001           5.000000e+03
# 伙食费中在外就餐花费g1002          2.000000e+03
# 去年平均每月购买日常用品支出g1006      3.000000e+01
# 去年平均每月本地交通支出g1008_imp    4.000000e+01
# 去年每月通信费支出g1009_imp       9.999999e+01
# 去年平均每月文化娱乐支出g1010_imp    5.000000e+01
# 去年购买衣物支出g1011_imp        9.000001e+02
# 去年旅游总支出g1018_imp         0.000000e+00
# 去年平均每月水/电/燃料费/物业g1005    1.500000e+02
# asset                    1.439698e+06
# total_income_imp         1.095200e+05
# 金融信息/银行储蓄卡               6.666444e-01
# 金融信息/伙食费                 3.999999e-01
# 风险汇报选择/旅游                3.000000e+04
# Name: 0, dtype: float64

# %%
k=d.drop(['风险等级'],axis=1)
k.iloc[0,:].as_matrix().reshape(1,22)
# Out:
# array([[2.00000000e+00, 3.00000000e+00, 1.00000000e+00, 3.00000000e+00,
#         2.00000000e+04, 1.50000000e+05, 2.00000000e+00, 2.00000000e+00,
#         5.00000000e+03, 2.00000000e+03, 3.00000000e+01, 4.00000000e+01,
#         9.99999924e+01, 5.00000000e+01, 9.00000122e+02, 0.00000000e+00,
#         1.50000000e+02, 1.43969812e+06, 1.09520000e+05, 6.66644445e-01,
#         3.99999920e-01, 3.00000000e+04]])

# %%
clf = joblib.load('g_model.pkl')
#print(d.iloc[0,1:])
#print(len(d.iloc[0,1:]))
#print(m)
y_true=y_test
y_pred=clf.predict_proba(k.iloc[0,:].as_matrix().reshape(1,22))
print(y_pred)
y=[]
for i in range(len(y_pred)):
    y_pred[i][0]=y_pred[i][0]-0.2
    y_pred[i][1]=y_pred[i][1]
    y_pred[i][2]=y_pred[i][2]
    y_pred[i][3]=y_pred[i][3]
    y_pred[i][4]=y_pred[i][4]
    max_value=max(y_pred[i])
    for j in range(len(y_pred[i])):
        if max_value==y_pred[i][j]:
            y.append(j)
                
target_names = ['class 0', 'class 1', 'class 2','class 3','class 4']
print(classification_report(y_true,y,target_names = target_names ))
# Out:
# [ 2019-09-05 22:02:48,550][cascade_classifier.transform] X_groups_test.shape=[(1, 22)]
# [ 2019-09-05 22:02:48,555][cascade_classifier.transform] group_dims=[22]
# [ 2019-09-05 22:02:48,559][cascade_classifier.transform] X_test.shape=(1, 22)
# [ 2019-09-05 22:02:48,562][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(1, 22)
# [ 2019-09-05 22:02:49,731][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(1, 42)
# [[0.22491634 0.24625485 0.20655198 0.23134781 0.09092904]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-254-edd8fef24431> in <module>()
#      19
#      20 target_names = ['class 0', 'class 1', 'class 2','class 3','class 4']
# ---> 21 print(classification_report(y_true,y,target_names = target_names ))
#
# d:\python\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict)
#    1850     """
#    1851
# -> 1852     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1853
#    1854     labels_given = True
#
# d:\python\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# d:\python\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [406, 1]

# %%
X_test.iloc[0,:].as_matrix().reshape(22,1).shape
# Out:
# (22, 1)
